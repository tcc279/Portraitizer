# %% [markdown]
# ## Neural Style Tranfer
#
# This notebook utilizes cysmith's Neural Style Transfer combined with the binary mask and preprocessed portrait
# created using the notebook Image Preprocessing as wellas my original art

# %%
#name of the portrait

x = "Jone_Cho"

#initialize counter j

j = 0

# %%
#this is the entire list of art that can be used

'''pic = ["420", "acid", "acid_levels", "BK", "chase", "circles"\
       "clown","croc","desert_dreams","dreams","drip_warp"\
       "elements","entourage","eric_anders","garden","goldface"\
       "jackson","kicked_out","kpop","LA","light_tunnel", "macro_element"\
       "melt", "mess", "mirage","never_settle","pink_aqua","planet"\
       "portrait","rain_bones","rainbow_tongue","random","roses","run"\
       "scifi","sketch", "skull","soho","space", "squid", "subway"\
       "toxic","uv","warp_old","watermelon"\
       "highnoon", "tallgeese","SI","NYC", "new_year", "natalia"]  '''

#for purposes of this notebook, I will only iterate on 3 pieces of art

pic = ["desert_dreams", "kicked_out", "jackson"]

# %%
#for every piece of art specified in the list pic, this code will run the neural style transfer on the portrait
#output is saved at image_output

for i in pic:
    y = x + "_original_edit.jpg"
    z = x + "_mask_edit.jpg"
    a = x + "_masked_" + i
    b = i + ".png"
    # !python neural_style.py --content_img $y --style_imgs $b --max_size 1000 --max_iterations 1000 --style_mask --style_mask_imgs $z --img_name $a --verbose;
    
    j += 1
    print(a)
    print(j)
# Out:
# ---- RENDERING SINGLE IMAGE ----
#
#
# BUILDING VGG-19 NETWORK
# loading model weights...
# constructing layers...
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# LAYER GROUP 1
# --conv1_1 | shape=(1, 513, 423, 64) | weights_shape=(3, 3, 3, 64)
# --relu1_1 | shape=(1, 513, 423, 64) | bias_shape=(64,)
# --conv1_2 | shape=(1, 513, 423, 64) | weights_shape=(3, 3, 64, 64)
# --relu1_2 | shape=(1, 513, 423, 64) | bias_shape=(64,)
# --pool1   | shape=(1, 257, 212, 64)
# LAYER GROUP 2
# --conv2_1 | shape=(1, 257, 212, 128) | weights_shape=(3, 3, 64, 128)
# --relu2_1 | shape=(1, 257, 212, 128) | bias_shape=(128,)
# --conv2_2 | shape=(1, 257, 212, 128) | weights_shape=(3, 3, 128, 128)
# ...
